# %% [markdown]
# # Texas Salary Prediction

# %% [markdown]
# This database has salary information for positions at all 113 agencies in the Texas state government. The Tribune obtained this data by requesting salary records from the state comptroller, as allowed by the Texas Public Information Act.

# %% [markdown]
# **Problem Statement**
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model which will help the Texas state government  team to know the payroll information of employees of the state of Texas.
#
# Task 3:-<br>
# ●	Who are the outliers in the salaries?<br>
# ●	What departments/roles have the biggest wage disparities between managers and employees?<br>
# ●	Have salaries and total compensations for some roles/ departments/ head-count changed over time?<br>

# %%
# Loading Basic Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task 1:-Prepare a complete data analysis report on the given data.

# %%
# Loading dataset
data=pd.read_csv('salary.csv')
pd.set_option("display.max_columns",None)

# %%
data.head(2)
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
#
#          ETHNICITY           GENDER                                    STATUS  \
# 0  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 1  WHITE            MALE             CTP - CLASSIFIED TEMPORARY PART-TIME
#
#   EMPLOY DATE  HRLY RATE  HRS PER WK  MONTHLY     ANNUAL  STATE NUMBER  \
# 0    02/18/88   75.96150        29.0  9545.82  114549.84        127717
# 1    02/01/15   81.04454         4.0  1404.77   16857.24        127717
#
#   duplicated  multiple_full_time_jobs combined_multiple_jobs  \
# 0       True                      NaN                    NaN
# 1       True                      NaN                    NaN
#
#    summed_annual_salary hide_from_search
# 0             131407.08              NaN
# 1                   NaN             True

# %%
data1=data.copy()

# %% [markdown]
# ### Domain Analysis
#
# * Agency:- Department IDs
# * Agency Name:- Name of Dapartments where employee worked
# * Last Name:- Last Name of Employee
# * First Name:- First Name of Employee
# * MI (Middle Initial):-Middle Name initial of Employee
# * Class title:- Job title / Designation of Employee
# * Ethnicity:- origin of Employee from which group he or she belongs
# * Gender:- gender of Employee
# * Status:- It has type of job like part time, full time, regular, temporary etc.
# * Employ Date:- Joining date
# * Hourly rate:- Hourly paid amount
# * Hrs per week:- Working Hours
# * Monthly (Monthly income):- Monthly salary
# * Annual (Annual Income):-Annual salary
# * State number

# %% [markdown]
# **Annual is a output variable and remaining features are input variable**

# %% [markdown]
# # Basic Checks

# %%
data.shape   ## Number of rows and columns
# Out:
# (149481, 21)

# %%
data.info()  #Memory Status
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149481 entries, 0 to 149480
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   AGENCY                   149481 non-null  int64
#  1   AGENCY NAME              149481 non-null  object
#  2   LAST NAME                149481 non-null  object
#  3   FIRST NAME               149481 non-null  object
#  4   MI                       149481 non-null  object
#  5   CLASS CODE               149481 non-null  object
#  6   CLASS TITLE              149481 non-null  object
#  7   ETHNICITY                149481 non-null  object
#  8   GENDER                   149481 non-null  object
#  9   STATUS                   149481 non-null  object
#  10  EMPLOY DATE              149481 non-null  object
#  11  HRLY RATE                149481 non-null  float64
#  12  HRS PER WK               149481 non-null  float64
#  13  MONTHLY                  149481 non-null  float64
#  14  ANNUAL                   149481 non-null  float64
#  15  STATE NUMBER             149481 non-null  int64
#  16  duplicated               143 non-null     object
#  17  multiple_full_time_jobs  14 non-null      float64
#  18  combined_multiple_jobs   97 non-null      object
#  19  summed_annual_salary     16 non-null      float64
#  20  hide_from_search         16 non-null      object
# dtypes: float64(6), int64(2), object(13)
# memory usage: 23.9+ MB

# %%
data.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER',
#        'duplicated', 'multiple_full_time_jobs', 'combined_multiple_jobs',
#        'summed_annual_salary', 'hide_from_search'],
#       dtype='object')

# %%
# Statistical Analysis
data.describe().T
# Out:
#                             count           mean            std      min  \
# AGENCY                   149481.0     545.736288     139.057691    101.0
# HRLY RATE                149481.0       0.346488       4.211485      0.0
# HRS PER WK               149481.0      39.714918       2.323855      1.0
# MONTHLY                  149481.0    4226.184248    2093.111691     50.0
# ANNUAL                   149481.0   50714.210973   25117.340292    600.0
# STATE NUMBER             149481.0  565193.023521  478621.220542      1.0
# multiple_full_time_jobs      14.0       1.000000       0.000000      1.0
# summed_annual_salary         16.0   74303.955000   51925.944282  18000.0
#
#                                25%        50%         75%           max
# AGENCY                      529.00     530.00      696.00  9.300000e+02
# HRLY RATE                     0.00       0.00        0.00  1.177885e+02
# HRS PER WK                   40.00      40.00       40.00  7.000000e+01
# MONTHLY                    3019.84    3720.17     4865.81  4.612500e+04
# ANNUAL                    36238.08   44642.04    58389.72  5.535000e+05
# STATE NUMBER             113334.00  346373.00  1100500.00  1.271604e+06
# multiple_full_time_jobs       1.00       1.00        1.00  1.000000e+00
# summed_annual_salary      32962.50   48063.30   123751.77  1.713834e+05

# %% [markdown]
# * Maximum hourly rate is $117.78
#
# * Maximum working hours per week is 70
#
# * Average montly salary is $4226.18<br>
#
# * Average annual salary is $50714.21

# %%
data.describe(include='O')
# Out:
#                                               AGENCY NAME  \
# count                                              149481
# unique                                                113
# top     HEALTH AND HUMAN SERVICES COMMISSION          ...
# freq                                                36667
#
#                              LAST NAME                      FIRST NAME  \
# count                           149481                          149481
# unique                           38675                           23559
# top     SMITH                           MICHAEL
# freq                              1243                            1843
#
#             MI CLASS CODE                                        CLASS TITLE  \
# count   149481     149481                                             149481
# unique      27       1481                                               1422
# top              4504      CORREC  OFFICER IV                            ...
# freq     38408       9267                                               9267
#
#               ETHNICITY           GENDER  \
# count            149481           149481
# unique                6                2
# top     WHITE            FEMALE
# freq              67142            85328
#
#                                           STATUS EMPLOY DATE duplicated  \
# count                                     149481      149481        143
# unique                                        11        6295          1
# top     CRF - CLASSIFIED REGULAR FULL-TIME          09/01/17       True
# freq                                      142502       12359        143
#
#        combined_multiple_jobs hide_from_search
# count                      97               16
# unique                      1                1
# top                      True             True
# freq                       97               16

# %%
# Categorical columns
cat_cols=data.select_dtypes(include='O')
cat_cols.columns
# Out:
# Index(['AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'duplicated', 'combined_multiple_jobs', 'hide_from_search'],
#       dtype='object')

# %%
# Numerical columns
num_cols=data.select_dtypes(include=['int64','float64'])
num_cols.columns
# Out:
# Index(['AGENCY', 'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL',
#        'STATE NUMBER', 'multiple_full_time_jobs', 'summed_annual_salary'],
#       dtype='object')

# %%
# Unique values in categorical columns
for i in cat_cols:
    print(i)
    print(data[i].unique())
    print('*****************************************************************************************')
# Out:
# AGENCY NAME
# ['COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECTION '
#  'OFFICE OF COURT ADMINISTRATION                    '
#  'TEXAS DEPARTMENT OF CRIMINAL JUSTICE              '
#  'OFFICE OF THE ATTORNEY GENERAL                    '
#  'TEXAS DEPARTMENT OF TRANSPORTATION                '
#  'TEXAS BEHAVIORAL HEALTH EXECUTIVE COUNCIL         '
#  'BOARD OF EXAMINERS OF PSYCHOLOGISTS               '
#  'DEPARTMENT OF STATE HEALTH SERVICES               '
#  'DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES      '
#  'HEALTH AND HUMAN SERVICES COMMISSION              '
#  'DEPARTMENT OF AGRICULTURE                         '
#  'SCHOOL FOR THE BLIND AND VISUALLY IMPAIRED        '
#  'SCHOOL FOR THE DEAF                               '
#  'SENATE                                            '
#  'LEGISLATIVE BUDGET BOARD                          '
#  'HOUSE OF REPRESENTATIVES                          '
#  'TEXAS FACILITIES COMMISSION                       '
#  'STATE PRESERVATION BOARD                          '
#  'TEXAS LEGISLATIVE COUNCIL                         '
#  'LEGISLATIVE REFERENCE LIBRARY                     '
#  'SUPREME COURT OF TEXAS                            '
#  'CT CRIM APPEALS                                   '
#  'OFFICE OF STATE PROSECUTING ATTORNEY              '
#  'OFFICE OF CAPITAL AND FORENSIC WRITS              '
#  'FIRST COURT OF APPEALS DISTRICT                   '
#  'SECOND COURT OF APPEALS DISTRICT                  '
#  'THIRD COURT OF APPEALS DISTRICT                   '
#  'FOURTH COURT OF APPEALS DISTRICT                  '
#  'FIFTH COURT OF APPEALS DISTRICT                   '
#  'SIXTH COURT OF APPEALS DISTRICT                   '
#  'SEVENTH COURT OF APPEALS DISTRICT                 '
#  'EIGHTH COURT OF APPEALS DISTRICT                  '
#  'NINTH COURT OF APPEALS DISTRICT                   '
#  'TENTH COURT OF APPEALS DISTRICT                   '
#  'ELEVENTH COURT OF APPEALS DISTRICT                '
#  'TWELFTH COURT OF APPEALS DISTRICT                 '
#  'THIRTEENTH COURT OF APPEALS DISTRICT              '
#  'FOURTEENTH COURT OF APPEALS DISTRICT              '
#  'STATE COMMISSION ON JUDICIAL CONDUCT              '
#  'STATE LAW LIBRARY                                 '
#  "GOVERNOR'S OFFICE, TRUSTEE PROGRAMS               "
#  'OFFICE OF THE GOVERNOR                            '
#  'COMPTROLLER OF PUBLIC ACCOUNTS                    '
#  'LIBRARY AND ARCHIVES COMMISSION                   '
#  'SECRETARY OF STATE                                '
#  'DEPARTMENT OF INFORMATION RESOURCES               '
#  'TEXAS WORKFORCE COMMISSION                        '
#  'TEACHER RETIREMENT SYSTEM                         '
#  'TEXAS EMERGENCY SERVICES RETIREMENT SYSTEM        '
#  'REAL ESTATE COMMISSION                            '
#  'DEPARTMENT OF HOUSING AND COMMUNITY AFFAIRS       '
#  'STATE PENSION REVIEW BOARD                        '
#  'TEXAS BOND REVIEW BOARD                           '
#  'STATE OFFICE OF ADMINISTRATIVE HEARINGS           '
#  'TEXAS MILITARY DEPARTMENT                         '
#  'TEXAS VETERANS COMMISSION                         '
#  'DEPARTMENT OF PUBLIC SAFETY                       '
#  'COMMISSION ON LAW ENFORCEMENT OFFICER STANDARDS AN'
#  'OFFICE OF INJURED EMPLOYEE COUNSEL                '
#  'DEPARTMENT OF LICENSING AND REGULATION            '
#  'TEXAS DEPARTMENT OF INSURANCE                     '
#  'RAILROAD COMMISSION                               '
#  'BOARD OF PUBLIC ACCOUNTANCY                       '
#  'ALCOHOLIC BEVERAGE COMMISSION                     '
#  'BOARD OF ARCHITECTURAL EXAMINERS                  '
#  'TEXAS BOARD OF PROFESSIONAL ENGINEERS             '
#  'BOARD OF PROFESSIONAL LAND SURVEYING              '
#  'CREDIT UNION DEPARTMENT                           '
#  'PUBLIC UTILITY COMMISSION OF TEXAS                '
#  'OFFICE OF RISK MANAGEMENT                         '
#  'BOARD OF PROFESSIONAL GEOSCIENTISTS               '
#  'TEXAS MEDICAL BOARD                               '
#  'BOARD OF CHIROPRACTIC EXAMINERS                   '
#  'TEXAS FUNERAL SERVICE COMMISSION                  '
#  'BOARD OF PHARMACY                                 '
#  'EXECUTIVE COUNCIL OF PHYSICAL THERAPY & OCCUPATION'
#  'CANCER PREVENTION AND RESEARCH INSTITUTE OF TEXAS '
#  'TEXAS ANIMAL HEALTH COMMISSION                    '
#  'TEXAS DEPARTMENT OF MOTOR VEHICLES                '
#  'TEXAS JUVENILE JUSTICE DEPARTMENT                 '
#  'TEXAS EDUCATION AGENCY                            '
#  'TEXAS HIGHER EDUCATION COORDINATING BOARD         '
#  'PARKS AND WILDLIFE DEPARTMENT                     '
#  'TEXAS COMMISSION ON THE ARTS                      '
#  'COMPTROLLER OF PUBLIC ACCOUNTS, STATE ENERGY CONSE'
#  'TREASURY SAFEKEEPING TRUST COMPANY                '
#  'SUNSET ADVISORY COMMISSION                        '
#  "GENERAL LAND OFFICE AND VETERAN'S LAND BOARD      "
#  "STATE AUDITOR'S OFFICE                            "
#  'SECURITIES BOARD                                  '
#  'EMPLOYEES RETIREMENT SYSTEM                       '
#  'TEXAS PUBLIC FINANCE AUTHORITY                    '
#  'TEXAS ETHICS COMMISSION                           '
#  'OFFICE OF PUBLIC INSURANCE COUNSEL                '
#  'TEXAS LOTTERY COMMISSION                          '
#  'HEALTH PROFESSIONS COUNCIL                        '
#  'COMMISSION ON JAIL STANDARDS                      '
#  'TEXAS COMMISSION ON FIRE PROTECTION               '
#  'SAVINGS AND LOAN DEPARTMENT                       '
#  'DEPARTMENT OF BANKING                             '
#  'BOARD OF PLUMBING EXAMINERS                       '
#  'CONSUMER CREDIT COMMISSION                        '
#  'OFFICE OF PUBLIC UTILITY COUNSEL                  '
#  'TEXAS RACING COMMISSION                           '
#  'COMMISSION ON STATE EMERGENCY COMMUNICATION       '
#  'BOARD OF DENTAL EXAMINERS                         '
#  'BOARD OF NURSE EXAMINERS                          '
#  'OPTOMETRY BOARD                                   '
#  'BOARD OF VETERINARY MEDICAL EXAMINERS             '
#  'WATER DEVELOPMENT BOARD                           '
#  'TEXAS COMMISSION ON ENVIRONMENTAL QUALITY         '
#  'SOIL AND WATER CONSERVATION BOARD                 '
#  'TEXAS HISTORICAL COMMISSION                       ']
# *****************************************************************************************
# LAST NAME
# ['RUCKER                        ' 'SPECIA JR                     '
#  'ONTIVEROS                     ' ... 'TYSEN                         '
#  'WANCHO                        ' 'WELLBORN III                  ']
# *****************************************************************************************
# FIRST NAME
# ['MORTON                        ' 'JOHN                          '
#  'ESTHER                        ' ... 'ELITHIA                       '
#  'VASHYRA                       ' 'SCOTLAND                      ']
# *****************************************************************************************
# MI
# ['V' 'J' ' ' 'D' 'A' 'C' 'M' 'R' 'T' 'F' 'P' 'G' 'L' 'K' 'E' 'S' 'W' 'N'
#  'X' 'O' 'B' 'H' 'Y' 'I' 'Z' 'U' 'Q']
# *****************************************************************************************
# CLASS CODE
# ['JD25    ' '3524    ' '4504    ' ... 'E075    ' '9733    ' 'E096    ']
# *****************************************************************************************
# CLASS TITLE
# ['JUDGE, RETIRED                                    '
#  'GENERAL COUNSEL IV                                '
#  'CORREC  OFFICER IV                                ' ...
#  'CURATOR III                                       '
#  'CURATOR IV                                        '
#  'EQUIPMENT MAINT TECH I                            ']
# *****************************************************************************************
# ETHNICITY
# ['WHITE          ' 'HISPANIC       ' 'BLACK          ' 'OTHER          '
#  'AM INDIAN      ' 'ASIAN          ']
# *****************************************************************************************
# GENDER
# ['MALE           ' 'FEMALE         ']
# *****************************************************************************************
# STATUS
# ['URP - UNCLASSIFIED REGULAR PART-TIME    '
#  'CTP - CLASSIFIED TEMPORARY PART-TIME    '
#  'CRF - CLASSIFIED REGULAR FULL-TIME      '
#  'ERP - EXEMPT REGULAR PART-TIME          '
#  'CRP - CLASSIFIED REGULAR PART-TIME      '
#  'URF - UNCLASSIFIED REGULAR FULL-TIME    '
#  'CTP - CLASSIFIED TEMPORARY FULL-TIME    '
#  'UTF - UNCLASSIFIED TEMPORARY FULL-TIME  '
#  'UTP - UNCLASSIFIED TEMPORARY PART-TIME  '
#  'ERF - EXEMPT REGULAR FULL-TIME          '
#  'CTF - CLASSIFIED TEMPORARY FULL-TIME    ']
# *****************************************************************************************
# EMPLOY DATE
# ['02/18/88' '02/01/15' '02/01/20' ... '10/30/18' '06/09/05' '09/22/89']
# *****************************************************************************************
# duplicated
# [True nan]
# *****************************************************************************************
# combined_multiple_jobs
# [nan True]
# *****************************************************************************************
# hide_from_search
# [nan True]
# *****************************************************************************************

# %%
# Unique values in numerical columns
for i in num_cols:
    print(i)
    print(data[i].unique())
# Out:
# AGENCY
# [241 212 696 302 601 510 520 537 530 529 551 771 772 101 104 102 303 809
#  103 105 201 211 213 215 221 222 223 224 225 226 227 228 229 230 231 232
#  233 234 242 243 300 301 304 306 307 313 320 323 326 329 332 338 352 360
#  401 403 405 407 448 452 454 455 457 458 459 460 464 469 473 479 481 503
#  508 513 515 533 542 554 608 644 701 781 802 813 907 930 116 305 308 312
#  327 347 356 359 362 364 409 411 450 451 456 466 475 476 477 504 507 514
#  578 580 582 592 808]
# HRLY RATE
# [ 75.9615   81.04454  81.04453   0.       49.40717  28.58     25.
#   17.33     13.13     11.5      20.00002  14.82693  30.16251  16.01272
#   19.       67.30765  75.96     30.       16.17     13.5      52.
#   30.87     82.635    30.1      17.00001  28.88     16.33     66.37
#   17.00002  19.23     17.       33.66     46.7      28.85     15.10003
#   44.5673   17.45717  15.75     14.       56.44     55.49     25.86
#   27.9777   11.32413 117.78848  79.95813  34.25723  28.08311  11.43317
#   24.9998   11.32412  37.95808  85.16291  25.79703  18.30598  11.32401
#   11.3241   11.43852  11.32403  71.07391  11.32414  25.83471  71.06982
#   71.07392  11.32404  20.24447  11.73837  10.42365  29.7649   28.41882
#   28.82221  19.1689   76.34569  34.20696  11.44324  11.63612  13.34336
#   12.55817  31.06644  21.52511  24.39762  28.89445  94.73365  97.95458
#   16.8101   16.81009  25.30576  13.25     12.75     18.       12.5
#   17.25     16.75     13.       16.       18.25     14.5      17.5
#   15.5      13.75     15.       14.25     12.49999  16.25     13.75003
#   14.48     20.86     12.85     42.04     13.57     20.       13.56923
#   15.57692  26.1375   14.81538  12.8535   45.36     14.104    13.5634
#   12.2385   12.4435   11.71575  12.94     55.       14.29     12.67925
#   24.231    29.30475  45.       26.51     10.97775  26.99     13.2
#   30.99     11.65425  12.86     13.4685   40.       42.03     41.
#   12.       65.       24.436    16.31     11.78     12.50002  13.92
#   13.42     12.49996  14.78     14.19     11.56996  12.50001  12.16
#   12.53002  13.41998  10.71     11.57002  12.91     14.21     11.57001
#   12.4945   12.84     12.90998  17.49998  10.70809  18.27     12.52996
#   16.32     14.18608  19.77     10.55002  16.36     27.18     12.12998
#   17.57     11.00002  13.39996  12.20459  11.95     16.5      14.21002
#   11.25     14.02692  11.57065  13.42004  14.84     12.20002  11.
#   10.       35.       50.       50.74038  37.95     24.77423  37.0872
#   31.9362   36.75     32.76036  19.3725   11.85     12.01     13.7
#   13.04     12.93     11.74   ]
# HRS PER WK
# [29.    4.   40.   20.   16.   19.    7.   41.   30.   32.    8.   10.
#  50.   60.   55.   70.   18.   25.   27.   28.   11.   15.   24.   26.
#  36.   19.2  39.6  29.3  26.93  8.4  23.2   5.2  22.5   3.35 35.    4.15
#  12.    5.   19.6  38.8  13.5  19.04 36.25 36.24 33.   31.28 36.21 21.76
#  30.6  13.88 20.92 30.4   1.    6.   14.   17.2  22.   23.  ]
# MONTHLY
# [9545.82 1404.77 3284.27 ... 1120.6  5744.16 1017.46]
# ANNUAL
# [114549.84  16857.24  39411.24 ...  13447.2   68929.92  12209.52]
# STATE NUMBER
# [127717  59115 165030 ...  34266 123490 103583]
# multiple_full_time_jobs
# [nan  1.]
# summed_annual_salary
# [131407.08       nan 171383.4   31950.    33300.    33966.    39174.
#   35570.52  56952.6   21839.76 121200.    90000.   150000.    92400.
#   18000.    30312.84]

# %% [markdown]
# # Data Cleaning

# %%
#Rename the values having space in the columns

# %%
data['ETHNICITY']=data['ETHNICITY'].str.strip()

# %%
data['ETHNICITY'].unique()
# Out:
# array(['WHITE', 'HISPANIC', 'BLACK', 'OTHER', 'AM INDIAN', 'ASIAN'],
#       dtype=object)

# %%
## Removing space
data['GENDER']=data['GENDER'].str.strip()

# %%
data['ETHNICITY']=data['ETHNICITY'].str.strip()

# %%
data.isna().sum() # checking for missing values
# Out:
# AGENCY                          0
# AGENCY NAME                     0
# LAST NAME                       0
# FIRST NAME                      0
# MI                              0
# CLASS CODE                      0
# CLASS TITLE                     0
# ETHNICITY                       0
# GENDER                          0
# STATUS                          0
# EMPLOY DATE                     0
# HRLY RATE                       0
# HRS PER WK                      0
# MONTHLY                         0
# ANNUAL                          0
# STATE NUMBER                    0
# duplicated                 149338
# multiple_full_time_jobs    149467
# combined_multiple_jobs     149384
# summed_annual_salary       149465
# hide_from_search           149465
# dtype: int64

# %%
data.isna().sum()[data.isna().sum()>0]  ## Columns with missing values
# Out:
# duplicated                 149338
# multiple_full_time_jobs    149467
# combined_multiple_jobs     149384
# summed_annual_salary       149465
# hide_from_search           149465
# dtype: int64

# %%
data.isna().sum()[data.isna().sum()>0]*100/data.shape[0]  ## Percentage of missing values
# Out:
# duplicated                 99.904336
# multiple_full_time_jobs    99.990634
# combined_multiple_jobs     99.935109
# summed_annual_salary       99.989296
# hide_from_search           99.989296
# dtype: float64

# %%
# Dropping columns having more than 99% missing data
data.drop(['duplicated','multiple_full_time_jobs','combined_multiple_jobs','summed_annual_salary','hide_from_search'],axis=1,inplace=True)

# %%
#Renaming columns
data.rename(columns={'AGENCY NAME':'AGENCY_NAME','LAST NAME':'LAST_NAME','FIRST NAME':'FIRST_NAME','CLASS CODE':'CLASS_CODE','CLASS TITLE':'CLASS_TITLE','EMPLOY DATE':'EMPLOY_DATE','HRLY RATE':'HRLY_RATE','HRS PER WK':'HRS_PER_WK','STATE NUMBER':'STATE_NUMBER'},inplace=True)

# %%
data.head(1)
# Out:
#    AGENCY                                        AGENCY_NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
#
#                         LAST_NAME                      FIRST_NAME MI  \
# 0  RUCKER                          MORTON                          V
#
#   CLASS_CODE                                        CLASS_TITLE ETHNICITY  \
# 0   JD25      JUDGE, RETIRED                                ...     WHITE
#
#   GENDER                                    STATUS EMPLOY_DATE  HRLY_RATE  \
# 0   MALE  URP - UNCLASSIFIED REGULAR PART-TIME        02/18/88    75.9615
#
#    HRS_PER_WK  MONTHLY     ANNUAL  STATE_NUMBER
# 0        29.0  9545.82  114549.84        127717

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# ### Distplot<br>
# * Represents the distribution of numerical columns

# %%
# Numerical Data Analysis
num_col=data.select_dtypes(include=['int64','float64'])
plt.figure(figsize=(20,20))
num=1
for col in num_col:
    if num<=6:
        plt.subplot(3,3,num)
        sns.distplot(x=data[col])
        plt.xlabel(col)
    num+=1

# %% [markdown]
# ### Insights
# * Hrly rate has corrupted data because distribution is saturated to 0
# * almost all employees works 40hrs per week
# * almost all monthly salaries lies between range 0 and 20000, it is skewed distribution (Not Normally Distributed)
# * almost all annual salaries lies between range 0 and 20000, it is skewed distribution (Not Normally Distributed)

# %% [markdown]
# ### COUNT PLOT<br>
# * Gives the count of observations

# %%
# Categorical Data Analysis
cat_col=data[['ETHNICITY','GENDER','STATUS']]
plt.figure(figsize=(20,20))
num=1
for col in cat_col:
    if num<=3:
        plt.subplot(3,3,num)
        sns.countplot(x=data[col])
        plt.xlabel(col)
        plt.xticks(rotation = 90)
    num+=1

# %% [markdown]
# ## Insights
# * Number Female employees are more than Male employees
# * Most of employees has job type(status) CRF - CLASSIFIED REGULAR FULL-TIME.

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# ### SCATTER PLOT<br>
# * Checking for correlation

# %%
corr_cols=['HRLY_RATE',"HRS_PER_WK",'MONTHLY']
plt.figure(figsize=(10,2))
plot_num=1
for x in corr_cols:
    if plot_num<=4:
        plt.subplot(1,4,plot_num)
        sns.scatterplot(x=data[x],y=data['ANNUAL'])
        plt.xlabel(x)
    plot_num+=1
plt.tight_layout()

# %% [markdown]
# ## Insights
# * Hrs per week doesn't show any correlation with ANNUAL Income.
# * Monthly column has direct correlation with ANNUAL Income.
# * Most of the values from HRLY RATE are 0, ramining show correlation with target.

# %%
sns.barplot(x=data['GENDER'],y=data["ANNUAL"])
# Out:
# <Axes: xlabel='GENDER', ylabel='ANNUAL'>

# %%
sns.barplot(x=data['ETHNICITY'],y=data["ANNUAL"])
# Out:
# <Axes: xlabel='ETHNICITY', ylabel='ANNUAL'>

# %%
sns.barplot(x=data['STATUS'],y=data["ANNUAL"])
x=plt.xticks(rotation=90)

# %% [markdown]
# * Male employees are receiving more annual salary
# * ASIAN and White is sharing high salary
# * Exempt regular full time employees has more annual salary

# %% [markdown]
# # Multivariate Analysis

# %%
num_col=data[['HRS_PER_WK','MONTHLY','HRLY_RATE','ANNUAL']]
sns.pairplot(data=num_col)

# %%
sns.heatmap(data[['HRLY_RATE',"HRS_PER_WK",'MONTHLY','ANNUAL']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # PREPROCESSING

# %%
#### Checking Duplicate Values
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(5,2))
sns.histplot(x=data['HRLY_RATE'],kde=True)
# Out:
# <Axes: xlabel='HRLY_RATE', ylabel='Count'>

# %% [markdown]
# * Most values in hourly rate column is zero and hence data is corrupted

# %%
data.drop(['HRLY_RATE'],axis=1,inplace=True)

# %% [markdown]
# # OUTLIERS IN THE SALARIES

# %%
num_col=data[['HRS_PER_WK','MONTHLY','ANNUAL']]
plt.figure(figsize=(20,20))
num=1
for col in num_col:
    if num<=4:
        plt.subplot(3,3,num)
        sns.boxplot(x=data[col])
        plt.xlabel(col)

    num+=1

# %%
num_col=data[['HRS_PER_WK','MONTHLY','ANNUAL']]
for col in num_col:
    Q1=data[col].quantile(0.25)
    Q3=data[col].quantile(0.75)
    IQR=Q3-Q1
    lower=Q1-1.5*IQR
    upper=Q3+1.5*IQR
    print("***********")
    print("Column Name:",col)
    print("IQR  ",IQR)
    print("Lower  ",lower)
    print("Upper  ",upper)
    print("Outliers Percentage",len(data.loc[(data[col]<lower)|(data[col]>upper)])/len(data))
    print("***********")
# Out:
# ***********
# Column Name: HRS_PER_WK
# IQR   0.0
# Lower   40.0
# Upper   40.0
# Outliers Percentage 0.017453723215659515
# ***********
# ***********
# Column Name: MONTHLY
# IQR   1845.9700000000003
# Lower   250.88499999999976
# Upper   7634.765000000001
# Outliers Percentage 0.060415705005987384
# ***********
# ***********
# Column Name: ANNUAL
# IQR   22151.64
# Lower   3010.6200000000026
# Upper   91617.18
# Outliers Percentage 0.060415705005987384
# ***********

# %%
# Handling outliers forcolumn having less than 5% missing values
data.loc[(data['HRS_PER_WK']<lower)|(data['HRS_PER_WK']>upper),'HRS_PER_WK']=data['HRS_PER_WK'].median()

# %% [markdown]
# ## ENCODING

# %%
cat_col=data.select_dtypes(include=['object'])
cat_col.columns
# Out:
# Index(['AGENCY_NAME', 'LAST_NAME', 'FIRST_NAME', 'MI', 'CLASS_CODE',
#        'CLASS_TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY_DATE'],
#       dtype='object')

# %%
data['GENDER']=data['GENDER'].replace({'FEMALE':0,'MALE':1})

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
data['STATUS']=lb.fit_transform(data['STATUS'])
data['ETHNICITY']=lb.fit_transform(data['ETHNICITY'])

# %%
data.head(2)
# Out:
#    AGENCY                                        AGENCY_NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
#
#                         LAST_NAME                      FIRST_NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
#
#   CLASS_CODE                                        CLASS_TITLE  ETHNICITY  \
# 0   JD25      JUDGE, RETIRED                                ...          5
# 1   3524      GENERAL COUNSEL IV                            ...          5
#
#    GENDER  STATUS EMPLOY_DATE  HRS_PER_WK  MONTHLY     ANNUAL  STATE_NUMBER
# 0       1       8    02/18/88        40.0  9545.82  114549.84        127717
# 1       1       4    02/01/15        40.0  1404.77   16857.24        127717

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# ### Handling Employee date column

# %%
data['EMPLOY_DATE']=pd.to_datetime(data['EMPLOY_DATE'])
data['EMPLOY_DT']=data['EMPLOY_DATE'].dt.day
data['EMPLOY_Month']=data['EMPLOY_DATE'].dt.month
data['EMPLOY_YR']=data['EMPLOY_DATE'].dt.year

# %%
data.head(3)
# Out:
#    AGENCY                                        AGENCY_NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
#
#                         LAST_NAME                      FIRST_NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
#
#   CLASS_CODE                                        CLASS_TITLE  ETHNICITY  \
# 0   JD25      JUDGE, RETIRED                                ...          5
# 1   3524      GENERAL COUNSEL IV                            ...          5
# 2   JD25      JUDGE, RETIRED                                ...          5
#
#    GENDER  STATUS EMPLOY_DATE  HRS_PER_WK  MONTHLY     ANNUAL  STATE_NUMBER  \
# 0       1       8  1988-02-18        40.0  9545.82  114549.84        127717
# 1       1       4  2015-02-01        40.0  1404.77   16857.24        127717
# 2       1       8  2020-02-01        40.0  9545.82  114549.84         59115
#
#    EMPLOY_DT  EMPLOY_Month  EMPLOY_YR
# 0         18             2       1988
# 1          1             2       2015
# 2          1             2       2020

# %%
#calculating years of experiance based on joining date
from datetime import datetime
data['EMPLOY_DATE'] = pd.to_datetime(data['EMPLOY_DATE'])
current_date = datetime.now()  # Get current date and time
data['YRS_EXP']=(current_date -data['EMPLOY_DATE'] ).dt.days/365.25

# %%
data.head(3)
# Out:
#    AGENCY                                        AGENCY_NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
#
#                         LAST_NAME                      FIRST_NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
#
#   CLASS_CODE                                        CLASS_TITLE  ETHNICITY  \
# 0   JD25      JUDGE, RETIRED                                ...          5
# 1   3524      GENERAL COUNSEL IV                            ...          5
# 2   JD25      JUDGE, RETIRED                                ...          5
#
#    GENDER  STATUS EMPLOY_DATE  HRS_PER_WK  MONTHLY     ANNUAL  STATE_NUMBER  \
# 0       1       8  1988-02-18        40.0  9545.82  114549.84        127717
# 1       1       4  2015-02-01        40.0  1404.77   16857.24        127717
# 2       1       8  2020-02-01        40.0  9545.82  114549.84         59115
#
#    EMPLOY_DT  EMPLOY_Month  EMPLOY_YR    YRS_EXP
# 0         18             2       1988  35.542779
# 1          1             2       2015   8.588638
# 2          1             2       2020   3.589322

# %%
plt.figure(figsize=(10,2))
plt.scatter(x=data['YRS_EXP'],y=data['ANNUAL'],color = "green")

# %%
data.loc[data['YRS_EXP']<0]
# Out:
#         AGENCY                                        AGENCY_NAME  \
# 20904      405  DEPARTMENT OF PUBLIC SAFETY                   ...
# 88771      601  TEXAS DEPARTMENT OF TRANSPORTATION            ...
# 116978     696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 141891     102  HOUSE OF REPRESENTATIVES                      ...
# 148921     592  SOIL AND WATER CONSERVATION BOARD             ...
#
#                              LAST_NAME                      FIRST_NAME MI  \
# 20904   HARALSON                        JOE                             W
# 88771   HALFORD                         JULIA                           F
# 116978  JUDD                            ARTHUR                          G
# 141891  CRADDICK                        TOM                             R
# 148921  BRANDENBERGER                   DONALD                          C
#
#        CLASS_CODE                                        CLASS_TITLE  \
# 20904    9940      SERGEANT, DPS                                 ...
# 88771    0152      ADMINISTRATIVE ASST II                        ...
# 116978   4675      AGRICULTURE SPEC V                            ...
# 141891   7109      ELECTED OFFICIAL                              ...
# 148921   1576      PROGRAM SPECIALIST VII                        ...
#
#         ETHNICITY  GENDER  STATUS EMPLOY_DATE  HRS_PER_WK  MONTHLY    ANNUAL  \
# 20904           5       1       0  2071-10-06        40.0  7207.91  86494.92
# 88771           5       0       0  2072-08-01        40.0  3388.44  40661.28
# 116978          5       1       0  2069-07-14        40.0  4033.74  48404.88
# 141891          5       1       7  2069-01-14        40.0   600.00   7200.00
# 148921          5       1       0  2068-12-01        40.0  7658.41  91900.92
#
#         STATE_NUMBER  EMPLOY_DT  EMPLOY_Month  EMPLOY_YR    YRS_EXP
# 20904         171968          6            10       2071 -48.087611
# 88771         100209          1             8       2072 -48.908966
# 116978         68427         14             7       2069 -45.859001
# 141891        116511         14             1       2069 -45.363450
# 148921         96871          1            12       2068 -45.242984

# %%
# dropping irrelevant records
data.drop([20904,88771,116978,141891,148921],axis=0,inplace=True)

# %%
sns.lineplot(data=data,x='EMPLOY_YR',y='ANNUAL')
# Out:
# <Axes: xlabel='EMPLOY_YR', ylabel='ANNUAL'>

# %% [markdown]
# ### Dropping unwanted columns

# %%
data.head(1)
# Out:
#    AGENCY                                        AGENCY_NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
#
#                         LAST_NAME                      FIRST_NAME MI  \
# 0  RUCKER                          MORTON                          V
#
#   CLASS_CODE                                        CLASS_TITLE  ETHNICITY  \
# 0   JD25      JUDGE, RETIRED                                ...          5
#
#    GENDER  STATUS EMPLOY_DATE  HRS_PER_WK  MONTHLY     ANNUAL  STATE_NUMBER  \
# 0       1       8  1988-02-18        40.0  9545.82  114549.84        127717
#
#    EMPLOY_DT  EMPLOY_Month  EMPLOY_YR    YRS_EXP
# 0         18             2       1988  35.542779

# %%
data.drop(['AGENCY','AGENCY_NAME','LAST_NAME','FIRST_NAME','MI','CLASS_CODE','CLASS_TITLE','EMPLOY_DATE','STATE_NUMBER'],axis=1,inplace=True)

# %%
data.head(2)
# Out:
#    ETHNICITY  GENDER  STATUS  HRS_PER_WK  MONTHLY     ANNUAL  EMPLOY_DT  \
# 0          5       1       8        40.0  9545.82  114549.84         18
# 1          5       1       4        40.0  1404.77   16857.24          1
#
#    EMPLOY_Month  EMPLOY_YR    YRS_EXP
# 0             2       1988  35.542779
# 1             2       2015   8.588638

# %% [markdown]
# # SPLITING DATA

# %%
x=data.drop(['ANNUAL'],axis=1)
y=data['ANNUAL']

# %% [markdown]
# # SCALING OF DATA

# %%
from sklearn.preprocessing  import MinMaxScaler
scaler = MinMaxScaler()

# %%
x[['HRS_PER_WK','MONTHLY','YRS_EXP']]= scaler.fit_transform(x[['HRS_PER_WK','MONTHLY','YRS_EXP']])

# %%
y_trans=np.log(y)
y_trans.head()
# Out:
# 0    11.648765
# 1     9.732536
# 2    11.648765
# 3     9.732536
# 4    10.581806
# Name: ANNUAL, dtype: float64

# %% [markdown]
# # Task:2 Create a predictive model which will help theTexas state government  team to know the payroll information of employees of the state of Texas.

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_trans, test_size=0.2, random_state=42)

# %% [markdown]
# # LINEAR REGRESSION

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([11.11381265, 10.73482468, 10.79805933, ..., 11.0071107 ,
#        10.90868414, 10.6317097 ])

# %%
model.coef_
# Out:
# array([ 4.34347640e-03,  1.09986893e-02, -3.40608557e-02,  9.40358902e-14,
#         8.51834235e+00,  3.73702461e-03,  8.28905422e-02,  9.94598802e-01,
#         4.74043889e+01])

# %%
model.intercept_
# Out:
# -1999.7484848551323

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MAE 0.09337436975881568
# MSE 0.02267055650275624

# %%
RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
RMSE
# Out:
# 0.1505674483504195

# %%
r2score_lr=r2_score(y_test,y_pred)
print('r2 score LR',r2score_lr)
# Out:
# r2 score LR 0.8704678326529033

# %% [markdown]
# # KNN REGRESSOR

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
ypred_knn = knn.predict(x_test)

# %%
MSE=mean_squared_error(y_test,ypred_knn)
print('MSE is ',MSE)
MAE=mean_absolute_error(y_test,ypred_knn)
print('MAE is',MAE)
RMSE=np.sqrt(MSE)
print('RMSE is ',RMSE)
# Out:
# MSE is  0.04539451252328955
# MAE is 0.10588600087894444
# RMSE is  0.21305988013534963

# %%
r_squaredknn=r2_score(y_test,ypred_knn)
print('r2_score is',r_squaredknn)
# Out:
# r2_score is 0.7406305578739659

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor
dec = DecisionTreeRegressor()
dec.fit(x_train, y_train)
ypred_dec = dec.predict(x_test)

# %%
MSE=mean_squared_error(y_test,ypred_dec)
print('MSE is ',MSE)
MAE=mean_absolute_error(y_test,ypred_dec)
print('MAE is',MAE)
RMSE=np.sqrt(MSE)
print('RMSE is ',RMSE)
# Out:
# MSE is  1.85628189048061e-05
# MAE is 6.47781122692112e-05
# RMSE is  0.0043084589942119795

# %%
r_squareddt=r2_score(y_test,ypred_dec)
print('r2_score is',r_squareddt)
# Out:
# r2_score is 0.9998939381058194

# %% [markdown]
# # XGB REGRESSOR

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train, y_train)
ypred_xgb = xgb.predict(x_test)

# %%
MSE=mean_squared_error(y_test,ypred_xgb)
print('MSE is ',MSE)
MAE=mean_absolute_error(y_test,ypred_xgb)
print('MAE is',MAE)
RMSE=np.sqrt(MSE)
print('RMSE is ',RMSE)
r_squaredxgb=r2_score(y_test,ypred_xgb)
print('r_squared is',r_squaredxgb)
# Out:
# MSE is  1.9859131886666577e-05
# MAE is 0.0007228892289634539
# RMSE is  0.004456358590448773
# r_squared is 0.9998865313961481

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
rf =  RandomForestRegressor()
rf.fit(x_train, y_train)
ypred_rf = rf.predict(x_test)

# %%
MSE=mean_squared_error(y_test,ypred_rf)
print('MSE is ',MSE)
MAE=mean_absolute_error(y_test,ypred_rf)
print('MAE is',MAE)
RMSE=np.sqrt(MSE)
print('RMSE is ',RMSE)
r_squaredrf=r2_score(y_test,ypred_rf)
print('r_squared is',r_squaredrf)
# Out:
# MSE is  2.0644054799585108e-05
# MAE is 6.667876242417661e-05
# RMSE is  0.004543572911221422
# r_squared is 0.9998820466025747

# %% [markdown]
# # GRADIENT BOOSTING REGRESSOR

# %%
from sklearn.ensemble import  GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train, y_train)
ypred_gb = gb.predict(x_test)

# %%
MSE=mean_squared_error(y_test,ypred_gb)
print('MSE is ',MSE)
MAE=mean_absolute_error(y_test,ypred_gb)
print('MAE is',MAE)
RMSE=np.sqrt(MSE)
print('RMSE is ',RMSE)
r_squaredgbr=r2_score(y_test,ypred_gb)
print('r_squared is',r_squaredgbr)
# Out:
# MSE is  2.840296650537975e-05
# MAE is 0.0024517731199052363
# RMSE is  0.005329443357929583
# r_squared is 0.9998377147111461

# %% [markdown]
# # Task 3.2:- What departments/roles have the biggest wage disparities between managers and employees?

# %%
df=data1.loc[data1['CLASS TITLE'].str.contains('MANAGER') | data1['CLASS TITLE'].str.contains('MGR'),['AGENCY NAME','CLASS TITLE','ANNUAL']]
pd.set_option("display.max_colwidth", None)
print('Maximum Salary for Manager: ',df.max().ANNUAL)
print('Minimum Salary for Manager: ',df.min().ANNUAL)
df.describe()
# Out:
# Maximum Salary for Manager:  295640.4
# Minimum Salary for Manager:  14624.76
#               ANNUAL
# count    6577.000000
# mean    69398.799520
# std     28242.077466
# min     14624.760000
# 25%     44642.040000
# 50%     68844.000000
# 75%     84999.960000
# max    295640.400000

# %%
print('Department/roles have biggest wage:')
df[df['ANNUAL']==df.max().ANNUAL]
# Out:
# Department/roles have biggest wage:
#                                                AGENCY NAME  \
# 136754  TEXAS EDUCATION AGENCY
#
#                                                CLASS TITLE    ANNUAL
# 136754  PORTFOLIO MANAGER VI                                295640.4

# %%
print('Department/roles have lowest wage:')
df[df['ANNUAL']==df.min().ANNUAL]
# Out:
# Department/roles have lowest wage:
#                                               AGENCY NAME  \
# 22342  DEPARTMENT OF PUBLIC SAFETY
#
#                                               CLASS TITLE    ANNUAL
# 22342  CUSTODIAL MGR I                                     14624.76

# %%
df1=data1.loc[~data1['CLASS TITLE'].str.contains('MANAGER') & ~data1['CLASS TITLE'].str.contains('MGR'),['AGENCY NAME','CLASS TITLE','ANNUAL']]
pd.set_option("display.max_colwidth", None)
#df5.head()
print('Max Salary for Employee',df1.max().ANNUAL)
print('Min Salary for Employee',df1.min().ANNUAL)
df1.describe()
# Out:
# Max Salary for Employee 553500.0
# Min Salary for Employee 600.0
#               ANNUAL
# count  142904.000000
# mean    49854.273261
# std     24625.299217
# min       600.000000
# 25%     36238.080000
# 50%     44642.040000
# 75%     56987.400000
# max    553500.000000

# %%
print('Department/roles have lowest wage:')
df1[df1['ANNUAL']==df1.max().ANNUAL]
# Out:
# Department/roles have lowest wage:
#                                               AGENCY NAME  \
# 83851  CANCER PREVENTION AND RESEARCH INSTITUTE OF TEXAS
#
#                                               CLASS TITLE    ANNUAL
# 83851  CHIEF SCIENTIFIC OFFICER                            553500.0

# %%
print('Department/roles have biggest wage:')
df1[df1['ANNUAL']==df1.min().ANNUAL]
# Out:
# Department/roles have biggest wage:
#                                                AGENCY NAME  \
# 142067  HOUSE OF REPRESENTATIVES
#
#                                                CLASS TITLE  ANNUAL
# 142067  ELECTED OFFICIALS STAFF                              600.0

# %% [markdown]
# # Difference Calculation

# %%
data1.loc[data1['CLASS TITLE'].str.contains('MANAGER') | data1['CLASS TITLE'].str.contains('MGR'),'CLASS TITLE']='MANAGER'

# %%
data1.loc[~data1['CLASS TITLE'].str.contains('MANAGER') & ~data1['CLASS TITLE'].str.contains('MGR'),'CLASS TITLE']='EMPLOYEE'

# %%
data_df1=data1.loc[:,['AGENCY NAME','CLASS TITLE','ANNUAL']]
data_df1.head()
# Out:
#                                           AGENCY NAME CLASS TITLE     ANNUAL
# 0  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECTION     EMPLOYEE  114549.84
# 1  OFFICE OF COURT ADMINISTRATION                        EMPLOYEE   16857.24
# 2  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECTION     EMPLOYEE  114549.84
# 3  OFFICE OF COURT ADMINISTRATION                        EMPLOYEE   16857.24
# 4  TEXAS DEPARTMENT OF CRIMINAL JUSTICE                  EMPLOYEE   39411.24

# %% [markdown]
# # Top departments which has biggest disparity between manager and employee salaries

# %%
# Create the pivot table
table = pd.pivot_table(data1, values='ANNUAL', index=['AGENCY NAME'], columns=['CLASS TITLE'], aggfunc=np.mean)

# Calculate the difference between 'manage' and 'employee' annual values
table['Difference'] = table['MANAGER'] - table['EMPLOYEE']


# Sort the pivot table by the 'Difference' column in descending order
sorted_table = table.sort_values(by='Difference', ascending=False)

# Drop the 'Difference' column if you don't need it anymore
sorted_table = sorted_table.drop(columns='Difference')

sorted_table.head()
# Out:
# CLASS TITLE                                              EMPLOYEE  \
# AGENCY NAME
# CANCER PREVENTION AND RESEARCH INSTITUTE OF TEXAS   114150.071250
# TEACHER RETIREMENT SYSTEM                            89952.002446
# EMPLOYEES RETIREMENT SYSTEM                          81715.002152
# BOARD OF NURSE EXAMINERS                             63194.071927
# STATE AUDITOR'S OFFICE                               79551.937143
#
# CLASS TITLE                                               MANAGER
# AGENCY NAME
# CANCER PREVENTION AND RESEARCH INSTITUTE OF TEXAS   214999.920000
# TEACHER RETIREMENT SYSTEM                           165494.782500
# EMPLOYEES RETIREMENT SYSTEM                         149489.171538
# BOARD OF NURSE EXAMINERS                            117027.240000
# STATE AUDITOR'S OFFICE                              126022.200000

# %% [markdown]
# # Task 3.3:- Have salaries and total compensations for some roles/ departments/ head-count changed over time

# %%
top_agencies=data1['AGENCY NAME'].value_counts().nlargest(10)
top_agencies.index.to_list()
# Out:
# ['HEALTH AND HUMAN SERVICES COMMISSION              ',
#  'TEXAS DEPARTMENT OF CRIMINAL JUSTICE              ',
#  'TEXAS DEPARTMENT OF TRANSPORTATION                ',
#  'DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES      ',
#  'DEPARTMENT OF PUBLIC SAFETY                       ',
#  'TEXAS WORKFORCE COMMISSION                        ',
#  'OFFICE OF THE ATTORNEY GENERAL                    ',
#  'DEPARTMENT OF STATE HEALTH SERVICES               ',
#  'PARKS AND WILDLIFE DEPARTMENT                     ',
#  'COMPTROLLER OF PUBLIC ACCOUNTS                    ']

# %%
new_data=data1.loc[data1['AGENCY NAME'].isin(top_agencies.index.to_list()),['AGENCY NAME','CLASS TITLE','EMPLOY DATE','ANNUAL']]
# Convert "Employ Date" to datetime format
new_data['EMPLOY DATE'] = pd.to_datetime(new_data['EMPLOY DATE'])
new_data['YEAR']=new_data['EMPLOY DATE'].dt.year

# Calculate the head count for each agency
agency_head_count = new_data.groupby('AGENCY NAME').size()

# Add the head count as a new column in the DataFrame
new_data['Head_Count'] = new_data['AGENCY NAME'].map(agency_head_count)

# Sort the DataFrame by the head count column in descending order
sorted_data = new_data.sort_values(by='Head_Count', ascending=False)
sorted_data.head()
# Out:
#                                               AGENCY NAME CLASS TITLE  \
# 52621  HEALTH AND HUMAN SERVICES COMMISSION                  EMPLOYEE
# 43732  HEALTH AND HUMAN SERVICES COMMISSION                  EMPLOYEE
# 43734  HEALTH AND HUMAN SERVICES COMMISSION                  EMPLOYEE
# 43735  HEALTH AND HUMAN SERVICES COMMISSION                  EMPLOYEE
# 43736  HEALTH AND HUMAN SERVICES COMMISSION                  EMPLOYEE
#
#       EMPLOY DATE    ANNUAL  YEAR  Head_Count
# 52621  2019-05-06  23781.00  2019       36667
# 43732  2004-09-01  39706.32  2004       36667
# 43734  2013-11-04  32692.80  2013       36667
# 43735  2017-09-01  25532.64  2017       36667
# 43736  2019-10-07  29520.96  2019       36667

# %%
# Create the pivot table
table = pd.pivot_table(sorted_data, values='ANNUAL', index=['AGENCY NAME', 'Head_Count'], columns=['YEAR'], aggfunc=np.mean)
# Sort the pivot table by the 'Difference' column in descending order
sorted_table = table.sort_index(level='Head_Count', ascending=False)
# Fill NaN values with 0 using applymap
sorted_table_filled = sorted_table.applymap(lambda x: x if pd.notna(x) else 0)
# Reset the index to remove 'Head_Count' from the index levels
sorted_table_filled = sorted_table_filled.reset_index(level='Head_Count')
# Remove the 'Head_Count' column
sorted_table_filled = sorted_table_filled.drop(columns='Head_Count')

sorted_table_filled.head()
# Out:
# YEAR                                                   1973  1976      1977  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.0   0.0      0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                    0.0   0.0      0.00
# TEXAS DEPARTMENT OF TRANSPORTATION                  68796.0   0.0  90300.36
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.0   0.0      0.00
# DEPARTMENT OF PUBLIC SAFETY                             0.0   0.0  87257.46
#
# YEAR                                                    1978       1979  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.00       0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                    0.00  199366.56
# TEXAS DEPARTMENT OF TRANSPORTATION                  84478.92   83987.76
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.00       0.00
# DEPARTMENT OF PUBLIC SAFETY                         58573.14   74561.24
#
# YEAR                                                    1980      1981  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.00      0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                64842.42  43835.76
# TEXAS DEPARTMENT OF TRANSPORTATION                  48431.88  74044.64
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.00      0.00
# DEPARTMENT OF PUBLIC SAFETY                         90000.00  98479.68
#
# YEAR                                                     1982       1983  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                     0.00       0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                 45873.36       0.00
# TEXAS DEPARTMENT OF TRANSPORTATION                  126103.41  127674.56
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES             0.00       0.00
# DEPARTMENT OF PUBLIC SAFETY                          81713.64   71764.08
#
# YEAR                                                        1984  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                58386.750000
# TEXAS DEPARTMENT OF TRANSPORTATION                  88273.832727
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         67036.890000
#
# YEAR                                                         1985  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                     0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                 54514.980000
# TEXAS DEPARTMENT OF TRANSPORTATION                   83221.232727
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES             0.000000
# DEPARTMENT OF PUBLIC SAFETY                         117665.360000
#
# YEAR                                                         1986  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                     0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                112723.680000
# TEXAS DEPARTMENT OF TRANSPORTATION                   85253.425263
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES             0.000000
# DEPARTMENT OF PUBLIC SAFETY                          96767.931429
#
# YEAR                                                        1987  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                57023.946667
# TEXAS DEPARTMENT OF TRANSPORTATION                  77291.341224
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         86545.596923
#
# YEAR                                                        1988  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                81919.320000
# TEXAS DEPARTMENT OF TRANSPORTATION                  96663.682759
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         96185.102400
#
# YEAR                                                        1989  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                63252.960000
# TEXAS DEPARTMENT OF TRANSPORTATION                  78957.952131
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         84152.508571
#
# YEAR                                                        1990  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                59279.276364
# TEXAS DEPARTMENT OF TRANSPORTATION                  71329.901333
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         78629.467200
#
# YEAR                                                        1991  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                60622.155429
# TEXAS DEPARTMENT OF TRANSPORTATION                  92568.347368
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.000000
# DEPARTMENT OF PUBLIC SAFETY                         74928.584000
#
# YEAR                                                        1992  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                53914.313684
# TEXAS DEPARTMENT OF TRANSPORTATION                  81016.456709
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        60155.924870
# DEPARTMENT OF PUBLIC SAFETY                         66778.836000
#
# YEAR                                                        1993  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                36509.760000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                49414.343111
# TEXAS DEPARTMENT OF TRANSPORTATION                  70872.799266
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        55415.709474
# DEPARTMENT OF PUBLIC SAFETY                         86125.169412
#
# YEAR                                                         1994  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                110735.400000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                 50364.121101
# TEXAS DEPARTMENT OF TRANSPORTATION                   72993.715528
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES         62004.977143
# DEPARTMENT OF PUBLIC SAFETY                          90301.686486
#
# YEAR                                                        1995  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                47919.558165
# TEXAS DEPARTMENT OF TRANSPORTATION                  77608.071818
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        61803.532000
# DEPARTMENT OF PUBLIC SAFETY                         83580.096000
#
# YEAR                                                        1996  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.000000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                46906.211946
# TEXAS DEPARTMENT OF TRANSPORTATION                  69681.286545
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        59920.686400
# DEPARTMENT OF PUBLIC SAFETY                         80263.376471
#
# YEAR                                                        1997  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                72623.640000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                46319.502574
# TEXAS DEPARTMENT OF TRANSPORTATION                  73101.089032
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        61058.798049
# DEPARTMENT OF PUBLIC SAFETY                         85962.376364
#
# YEAR                                                        1998  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                70799.840000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                47343.735619
# TEXAS DEPARTMENT OF TRANSPORTATION                  68089.206667
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        58964.752500
# DEPARTMENT OF PUBLIC SAFETY                         79364.752836
#
# YEAR                                                        1999  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                92784.480000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                46523.519326
# TEXAS DEPARTMENT OF TRANSPORTATION                  72509.734687
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        59460.761633
# DEPARTMENT OF PUBLIC SAFETY                         75386.402609
#
# YEAR                                                         2000  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                116475.060000
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                 45205.900146
# TEXAS DEPARTMENT OF TRANSPORTATION                   67466.577616
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES         59853.129057
# DEPARTMENT OF PUBLIC SAFETY                          70194.910755
#
# YEAR                                                        2001  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                93229.645714
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45300.761053
# TEXAS DEPARTMENT OF TRANSPORTATION                  65689.304701
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        57282.237000
# DEPARTMENT OF PUBLIC SAFETY                         66173.451081
#
# YEAR                                                        2002  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                84741.770769
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45480.139022
# TEXAS DEPARTMENT OF TRANSPORTATION                  70158.658028
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        59570.109744
# DEPARTMENT OF PUBLIC SAFETY                         74475.213405
#
# YEAR                                                        2003  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                62181.674595
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45698.422212
# TEXAS DEPARTMENT OF TRANSPORTATION                  69203.699259
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        57523.285532
# DEPARTMENT OF PUBLIC SAFETY                         72564.824795
#
# YEAR                                                        2004  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                49640.092397
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                46214.777200
# TEXAS DEPARTMENT OF TRANSPORTATION                  62155.406006
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        58049.363077
# DEPARTMENT OF PUBLIC SAFETY                         67393.783770
#
# YEAR                                                        2005  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                54656.938605
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45203.525150
# TEXAS DEPARTMENT OF TRANSPORTATION                  62723.477121
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        56480.383311
# DEPARTMENT OF PUBLIC SAFETY                         65477.916364
#
# YEAR                                                        2006  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                46229.085802
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45437.395642
# TEXAS DEPARTMENT OF TRANSPORTATION                  62243.682171
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        53354.477400
# DEPARTMENT OF PUBLIC SAFETY                         63884.012440
#
# YEAR                                                        2007  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                48325.841739
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                44957.230882
# TEXAS DEPARTMENT OF TRANSPORTATION                  59585.179891
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        51890.688776
# DEPARTMENT OF PUBLIC SAFETY                         68639.632744
#
# YEAR                                                        2008  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                43375.715441
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                44678.290979
# TEXAS DEPARTMENT OF TRANSPORTATION                  65274.241951
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        54081.563916
# DEPARTMENT OF PUBLIC SAFETY                         62575.790374
#
# YEAR                                                        2009  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                43313.740984
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                44538.649550
# TEXAS DEPARTMENT OF TRANSPORTATION                  71351.444211
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        53798.034882
# DEPARTMENT OF PUBLIC SAFETY                         67165.603099
#
# YEAR                                                        2010  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                45088.606082
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                45452.847677
# TEXAS DEPARTMENT OF TRANSPORTATION                  61594.459535
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        54587.167233
# DEPARTMENT OF PUBLIC SAFETY                         65528.209892
#
# YEAR                                                        2011  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                42490.485141
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                44408.727308
# TEXAS DEPARTMENT OF TRANSPORTATION                  55251.536943
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        57243.289507
# DEPARTMENT OF PUBLIC SAFETY                         62777.049310
#
# YEAR                                                        2012  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                44074.996456
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                44391.288800
# TEXAS DEPARTMENT OF TRANSPORTATION                  62232.403659
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        53956.748712
# DEPARTMENT OF PUBLIC SAFETY                         57172.315978
#
# YEAR                                                        2013  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                45849.059494
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                43182.178619
# TEXAS DEPARTMENT OF TRANSPORTATION                  59273.212444
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        53654.563706
# DEPARTMENT OF PUBLIC SAFETY                         58432.061933
#
# YEAR                                                        2014  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                48616.736262
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                42484.249029
# TEXAS DEPARTMENT OF TRANSPORTATION                  59193.820060
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        55397.427236
# DEPARTMENT OF PUBLIC SAFETY                         57112.606479
#
# YEAR                                                        2015  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                48731.435016
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                41448.026196
# TEXAS DEPARTMENT OF TRANSPORTATION                  54589.170769
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        53718.471632
# DEPARTMENT OF PUBLIC SAFETY                         58812.108023
#
# YEAR                                                        2016  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                53667.489638
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                40881.028964
# TEXAS DEPARTMENT OF TRANSPORTATION                  57797.038515
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        52638.870938
# DEPARTMENT OF PUBLIC SAFETY                         53861.000045
#
# YEAR                                                        2017  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                41771.931249
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                40190.648500
# TEXAS DEPARTMENT OF TRANSPORTATION                  51318.659070
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        51352.832698
# DEPARTMENT OF PUBLIC SAFETY                         53192.138779
#
# YEAR                                                        2018  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                40004.603892
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                37858.176204
# TEXAS DEPARTMENT OF TRANSPORTATION                  50780.927089
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        48273.321394
# DEPARTMENT OF PUBLIC SAFETY                         49637.211870
#
# YEAR                                                        2019  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                36707.124052
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                36440.585280
# TEXAS DEPARTMENT OF TRANSPORTATION                  47096.699122
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        45140.703652
# DEPARTMENT OF PUBLIC SAFETY                         41537.931923
#
# YEAR                                                        2020      2069  \
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                35422.958529      0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                36255.441267  48404.88
# TEXAS DEPARTMENT OF TRANSPORTATION                  42170.490649      0.00
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES        45278.796829      0.00
# DEPARTMENT OF PUBLIC SAFETY                         41499.392316      0.00
#
# YEAR                                                    2071      2072
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                    0.00      0.00
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                    0.00      0.00
# TEXAS DEPARTMENT OF TRANSPORTATION                      0.00  40661.28
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES            0.00      0.00
# DEPARTMENT OF PUBLIC SAFETY                         86494.92      0.00

# %%
agencies = top_agencies.index.to_list()

# %%
plt.figure(figsize=(10, 6))
for agency in agencies:
    agency_data = sorted_table_filled.iloc[sorted_table_filled.index==agency]
    plt.plot(agency_data.columns, agency_data.values[0], marker='o', label=agency_data.index[0])
    plt.xlabel('Year')
    plt.ylabel('Annual Salary')
    plt.title(agency_data.index[0])
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Model Comparison Report

# %%
## Model Comparison Report

model_results = pd.DataFrame(columns=['Model', 'R-squared', 'MAE', 'RMSE'])

# %%
models = ['Linear Regression','Decision Tree','KNN','Random Forest','Gradient Boosting regressor','XGBoost']
r_squared = [0.8704,0.9998,0.7405,0.9998,0.9998,0.9998]
mae = [0.09338,6.9568,0.1059,6.5725,0.00245,0.00072]

rmse = [0.1505,0.0043,0.2131,0.0047,0.0053,0.0044]

# %%
# Populate the DataFrame
model_results['Model'] = models
model_results['R-squared'] = r_squared
model_results['MAE'] = mae
model_results['RMSE'] = rmse

# Display the results
model_results.head()
# Out:
#                          Model  R-squared      MAE    RMSE
# 0            Linear Regression     0.8704  0.09338  0.1505
# 1                Decision Tree     0.9998  6.95680  0.0043
# 2                          KNN     0.7405  0.10590  0.2131
# 3                Random Forest     0.9998  6.57250  0.0047
# 4  Gradient Boosting regressor     0.9998  0.00245  0.0053

# %%
model_results.to_csv('model_comparison_report.csv')

# %%
vs=pd.read_csv('model_comparison_report.csv')
vs.drop('Unnamed: 0',axis=1,inplace=True)
vs.head()
# Out:
#                          Model  R-squared      MAE    RMSE
# 0            Linear Regression     0.8704  0.09338  0.1505
# 1                Decision Tree     0.9998  6.95680  0.0043
# 2                          KNN     0.7405  0.10590  0.2131
# 3                Random Forest     0.9998  6.57250  0.0047
# 4  Gradient Boosting regressor     0.9998  0.00245  0.0053

# %%
## Visualization


vs1=vs.drop('Model',axis=1)
#vs1.columns.to_list()

plt.figure(figsize=(20,10))
num =1
# Create a 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Iterate through metrics and corresponding subplot axis
for i, col in enumerate(vs1.columns.to_list()):
    sns.barplot(x='Model', y=col, data=vs, ax=axes[i])
    axes[i].set_xlabel('Models')
    axes[i].set_ylabel('Metrics')
    for tick in axes[i].get_xticklabels():
        tick.set_rotation(75)

    axes[i].set_title(col)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights
#
#     Decision Tree, Random Forest, Gradient Boosting, and XGBoost achieved near-perfect R2 scores (very close to 1), indicating excellent model performance in explaining the variance in the data.
#
#     K-Nearest Neighbors (KNN) had a lower R2 score compared to the ensemble methods, suggesting it might not capture the complexity of the data as effectively.
#
#     Linear Regression, while having a respectable R2 score, had a higher MAE and RMSE compared to the ensemble methods, indicating that its predictions had larger errors on average.
#
#     Gradient Boosting and XGBoost outperformed all other models with extremely low MAE and RMSE values, indicating very accurate predictions.
#
#     Decision Tree and Random Forest had high R2 scores but comparatively higher MAE values, which could suggest that they might overfit the data to some extent.
#
# Overall, based on the provided metrics, Gradient Boosting and XGBoost appear to be the top-performing models, offering high accuracy and low errors. However, further evaluation, such as cross-validation, should be conducted to ensure the models generalize well to new data. Additionally, considerations about model complexity and interpretability may influence the final model choice for deployment.

# %% [markdown]
# # Data Analysis and Model Selection Report

# %% [markdown]
# Introduction: This report details the challenges encountered during the analysis of the Texas Salary Prediction dataset and the techniques employed to address those challenges. The goal was to develop an accurate salary prediction model for employees based on various attributes.

# %% [markdown]
# **Challenges Faced**:<br>

# %% [markdown]
# ##### Missing Data:<br>
# **Challenge**: <br>
# The dataset contained missing values in several columns, which could potentially affect model performance.<br>
# **Technique**:<br>
# Missing values were handled using appropriate techniques based on the nature of the data. Categorical variables were imputed with mode values, while numerical variables were imputed using median values. This preserved data integrity without introducing bias.

# %% [markdown]
# ##### Categorical Variables:<br>
# **Challenge**:<br>
#     The dataset included categorical attributes such as Ethnicity, Gender, and Status, which needed to be converted into numerical format for model training.<br>
# **Technique**:<br>
#     Label encoding was applied to convert categorical variables into numerical values. This technique was suitable when the categorical attributes had an inherent ordinal relationship.

# %% [markdown]
# ##### Feature Scaling:<br>
# **Challenge**:<br>
# Numerical attributes had different scales such as Tenure Date,Monthly,Hourly Rate which could impact the performance of certain machine learning algorithms.<br>
# **Technique**:<br>
# Min-Max scaling was applied to scale numerical attributes to a common range between 0 and 1. This technique preserved the relationships between the variables while preventing any dominance of features with larger scales.

# %% [markdown]
# ##### Employee Experience Calculation:<br>
# **Challenge**:<br>
# Converting the "Employ Date" attribute to years of experience from the current date was necessary to include a valuable feature for predicting salaries.<br>
# **Technique**:<br>
# The difference in years between the current date and the "Employ Date" was calculated to determine the tenure in years. This tenure value was added as a feature for the predictive models.

# %% [markdown]
# ##### Model Selection:<br>
# **Challenge**:<br>
# Selecting the appropriate machine learning algorithms to predict salary accurately while avoiding overfitting and underfitting.<br>
# **Technique**: <br>Six algorithms were evaluated—Linear Regression, K-Nearest Neighbors (KNN), Decision Tree, Random Forest, XGBoost, and Gradient Boosting. Each algorithm was chosen based on its inherent properties and suitability for the dataset. Random Forest, XGBoost, and Gradient Boosting were preferred for their ability to capture complex relationships and reduce overfitting due to their ensemble and boosting techniques.

# %% [markdown]
# ##### Techniques Employed with Reasons:<br>
# **Handling Missing Data:**<br>
# Missing values were imputed using mode for categorical variables and median for numerical variables. This approach maintained data quality while minimizing distortion introduced by imputation. Using the mode and median also helped in handling skewed distributions.<br>
# **Label Encoding:**<br>
# Label encoding was chosen to convert categorical variables to numerical format. This technique was used for variables where an inherent order existed (e.g., Status,Ethnicity).<br>
# **Min-Max Scaling:**<br>
# Min-Max scaling was employed to normalize numerical attributes to a common scale. This ensured that all features contributed equally to the model and prevented larger-scaled features from dominating the learning process.<br>
# **Employee Experience Calculation:**<br>
# Converting the "Employ Date" to years of experience was accomplished by calculating the difference between the current date and the "Employ Date." This added an important temporal feature that could impact salary predictions.<br>
# **Model Selection:**<br>
# Linear Regression was chosen for its simplicity and interpretability, making it a good baseline model.
#
# Random Forest, XGBoost, and Gradient Boosting were selected due to their ability to handle complex relationships and reduce overfitting. XGBoost, in particular, was chosen for its ensemble approach that enhances model accuracy.
#
# K-Nearest Neighbors (KNN) and Decision Tree were also included to explore alternative modeling approaches and assess their performance on the dataset.<br>

# %% [markdown]
# ##### Conclusion:<br>
# The challenges faced during data analysis were addressed using appropriate techniques that maintained data integrity and improved model performance. Through careful handling of missing data, encoding categorical attributes, scaling features, calculating employee experience, and selecting suitable algorithms,a robust salary prediction model was developed. This model selection process led to the recommendation of employing the XGBoost algorithm due to its strong overall performance in terms of accuracy and robustness.
